# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

print(session.world_state)
print(session.player_states)
print(session.controllers)
print(session.assigned_roles)
# Out:
# phase='night' players=['太郎', '花子', '次郎', 'さくら', '健太'] public_events=[]
# {'太郎': PlayerState(memory=PlayerMemory(self_name='太郎', self_role='villager', beliefs={'花子': 'unknown', '次郎': 'unknown', 'さくら': 'unknown', '健太': 'unknown'}, suspicion={'花子': 0.5, '次郎': 0.5, 'さくら': 0.5, '健太': 0.5}, history=[]), input=PlayerInput(event=None, request=None), output=None), '花子': PlayerState(memory=PlayerMemory(self_name='花子', self_role='seer', beliefs={'太郎': 'unknown', '次郎': 'unknown', 'さくら': 'unknown', '健太': 'unknown'}, suspicion={'太郎': 0.5, '次郎': 0.5, 'さくら': 0.5, '健太': 0.5}, history=[]), input=PlayerInput(event=None, request=None), output=None), '次郎': PlayerState(memory=PlayerMemory(self_name='次郎', self_role='werewolf', beliefs={'太郎': 'unknown', '花子': 'unknown', 'さくら': 'unknown', '健太': 'unknown'}, suspicion={'太郎': 0.5, '花子': 0.5, 'さくら': 0.5, '健太': 0.5}, history=[]), input=PlayerInput(event=None, request=None), output=None), 'さくら': PlayerState(memory=PlayerMemory(self_name='さくら', self_role='villager', beliefs={'太郎': 'unknown', '花子': 'unknown', '次郎': 'unknown', '健太': 'unknown'}, suspicion={'太郎': 0.5, '花子': 0.5, '次郎': 0.5, '健太': 0.5}, history=[]), input=PlayerInput(event=None, request=None), output=None), '健太': PlayerState(memory=PlayerMemory(self_name='健太', self_role='madman', beliefs={'太郎': 'unknown', '花子': 'unknown', '次郎': 'unknown', 'さくら': 'unknown'}, suspicion={'太郎': 0.5, '花子': 0.5, '次郎': 0.5, 'さくら': 0.5}, history=[]), input=PlayerInput(event=None, request=None), output=None)}
# {'太郎': <src.core.controller.AIPlayerController object at 0x70dc1d604980>, '花子': <src.core.controller.AIPlayerController object at 0x70dc1dfd2f30>, '次郎': <src.core.controller.AIPlayerController object at 0x70dc1dfd2ab0>, 'さくら': <src.core.controller.AIPlayerController object at 0x70dc1dfd0dd0>, '健太': <src.core.controller.AIPlayerController object at 0x70dc1dfd0c50>}
# {'太郎': 'villager', '花子': 'seer', '次郎': 'werewolf', 'さくら': 'villager', '健太': 'madman'}

# %%
state = session.run_gm_step()
print(state)
# Out:
# === GMGraph result ===
# world_state=WorldState(phase='night', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[]) decision=GameDecision(events=None, requests={'太郎': PlayerRequest(request_type='use_ability', payload={'candidates': ['花子', '次郎', 'さくら', '健太']}), '花子': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '次郎', 'さくら', '健太']}), '次郎': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', 'さくら', '健太']}), 'さくら': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', '次郎', '健太']}), '健太': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', '次郎', 'さくら']})}, next_phase=None)
# world_state=WorldState(phase='night', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[]) decision=GameDecision(events=None, requests={'太郎': PlayerRequest(request_type='use_ability', payload={'candidates': ['花子', '次郎', 'さくら', '健太']}), '花子': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '次郎', 'さくら', '健太']}), '次郎': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', 'さくら', '健太']}), 'さくら': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', '次郎', '健太']}), '健太': PlayerRequest(request_type='use_ability', payload={'candidates': ['太郎', '花子', '次郎', 'さくら']})}, next_phase=None)

# %%
decision = session.dispatch(state.decision)
print(decision)
# Out:
# None
