# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

print(session.gm_state)
print(session.player_states)
print(session.controllers)
print(session.assigned_roles)
# Out:
# {'phase': 'night', 'players': ['太郎', '花子', '次郎', 'さくら', '健太'], 'public_events': []}
# ...

# %%
from src.game.setup.gm_setup import setup_game

players, roles, player_memories = setup_game()
players
roles
player_memories
# Out:
# {'太郎': {'self_name': '太郎',
#   'self_role': 'madman',
#   'beliefs': {'花子': 'unknown',
#    '次郎': 'unknown',
#    'さくら': 'unknown',
#    '健太': 'unknown'},
#   'suspicion': {'花子': 0.5, '次郎': 0.5, 'さくら': 0.5, '健太': 0.5},
#   'history': []},
#  '花子': {'self_name': '花子',
#   'self_role': 'seer',
#   'beliefs': {'太郎': 'unknown',
#    '次郎': 'unknown',
#    'さくら': 'unknown',
#    '健太': 'unknown'},
#   'suspicion': {'太郎': 0.5, '次郎': 0.5, 'さくら': 0.5, '健太': 0.5},
#   'history': []},
#  '次郎': {'self_name': '次郎',
#   'self_role': 'villager',
#   'beliefs': {'太郎': 'unknown',
#    '花子': 'unknown',
#    'さくら': 'unknown',
#    '健太': 'unknown'},
#   'suspicion': {'太郎': 0.5, '花子': 0.5, 'さくら': 0.5, '健太': 0.5},
#   'history': []},
#  'さくら': {'self_name': 'さくら',
#   'self_role': 'werewolf',
#   'beliefs': {'太郎': 'unknown',
#    '花子': 'unknown',
#    '次郎': 'unknown',
#    '健太': 'unknown'},
#   'suspicion': {'太郎': 0.5, '花子': 0.5, '次郎': 0.5, '健太': 0.5},
#   'history': []},
#  '健太': {'self_name': '健太',
# ...

# %%
# Out:
# '/home/soyu/Projects/LangGraph/ai-worf/werewolf_notebook/notebook'
