# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from rich.pretty import pprint

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

# pprint(session.world_state)
# pprint(session.controllers)
# pprint(session.assigned_roles)
# pprint(session.gm_internal)
# pprint(session.player_states)
# Out:
# WorldState(phase='night', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# {
# │   '太郎': <src.core.controller.AIPlayerController object at 0x7feeeb77f920>,
# │   '花子': <src.core.controller.AIPlayerController object at 0x7feeeb77f950>,
# │   '次郎': <src.core.controller.AIPlayerController object at 0x7feeeb77f980>,
# │   'さくら': <src.core.controller.AIPlayerController object at 0x7feeeb77f9b0>,
# │   '健太': <src.core.controller.AIPlayerController object at 0x7feeeb77fa10>
# }
# {'太郎': 'madman', '花子': 'villager', '次郎': 'werewolf', 'さくら': 'seer', '健太': 'villager'}
# GMInternalState(night_pending=['次郎', '健太', '太郎', '花子', 'さくら'], gm_event_cursor=0)
# {
# │   '太郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='太郎',
# │   │   │   self_role='madman',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 1.0}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=None),
# │   │   'output': None
# │   },
# │   '花子': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='花子',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=None),
# │   │   'output': None
# │   },
# │   '次郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='次郎',
# │   │   │   self_role='werewolf',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 1.0, 'madman': 0.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=None),
# │   │   'output': None
# │   },
# │   'さくら': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='さくら',
# │   │   │   self_role='seer',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.0, 'seer': 1.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=None),
# │   │   'output': None
# │   },
# │   '健太': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='健太',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0})
# │   │   │   },
# │   │   │   history=[]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=None),
# │   │   'output': None
# │   }
# }

# %%
session.run_night_phase()
pprint(session.world_state)
pprint(session.gm_internal)
pprint(session.player_states)
# Out:
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=[], gm_event_cursor=0)
# {
# │   '太郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='太郎',
# │   │   │   self_role='madman',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 1.0}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {
# │   │   │   │   │   'kind': 'reflection',
# │   │   │   │   │   'text': 'The empty payload suggests the request is vague, which fits my chaotic role but could force others to guess my intent. I should consider whether to reveal or hide my ability use to manipulate their uncertainty about who holds any special powers.'
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   '花子': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='花子',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {
# │   │   │   │   │   'kind': 'reflection',
# │   │   │   │   │   'text': 'My attempt to use an ability without specifying a target may raise questions about my intentions and could be interpreted as hesitation. I should consider how to adjust my behavior to maintain credibility while avoiding unnecessary suspicion.'
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   '次郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='次郎',
# │   │   │   self_role='werewolf',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 1.0, 'madman': 0.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {
# │   │   │   │   │   'kind': 'reflection',
# │   │   │   │   │   'text': "I sensed a request to activate an ability from the player I know is a werewolf, but without details it's unclear which power they intended. This creates ambiguity: are they trying to mislead, protect a teammate, or test reactions? I should consider coordinating night actions with them while keeping my own role hidden."
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=WerewolfAbility(kind='werewolf'))
# │   },
# │   'さくら': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='さくら',
# │   │   │   self_role='seer',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[
# │   │   │   │   GameEvent(event_type='divine_result', payload={'target': '次郎', 'role': 'werewolf'})
# │   │   │   ],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 1.0, 'madman': 0.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.0, 'seer': 1.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {
# │   │   │   │   │   'kind': 'analysis',
# │   │   │   │   │   'text': 'The empty use_ability request suggests the player may be uncertain about which ability to activate, possibly indicating a lack of information or a forced action. As seer I should monitor who initiates such requests to infer their role and possible hidden abilities. This ambiguity also creates an opportunity to probe for reactions from other players.'
# │   │   │   │   },
# │   │   │   │   {
# │   │   │   │   │   'kind': 'analysis',
# │   │   │   │   │   'text': 'Knowing the target is a confirmed werewolf gives me leverage to expose them, but I must decide whether to reveal this immediately or let suspicion build. I should also consider how other players might react if they suspect I have divine insight, as that could affect future use_ability requests and alliances.'
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(
# │   │   │   event=GameEvent(event_type='divine_result', payload={'target': '次郎', 'role': 'werewolf'}),
# │   │   │   request=None
# │   │   ),
# │   │   'output': None
# │   },
# │   '健太': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='健太',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.25, 'seer': 0.25, 'werewolf': 0.25, 'madman': 0.25}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {
# │   │   │   │   │   'kind': 'analysis',
# │   │   │   │   │   'text': 'The empty ability request hints at uncertainty or a hidden agenda from the initiator. Given my certainty of being a villager, I should interpret this as a potential probe by a seer or a feint by a werewolf. Thus I will hold back any counteraction until more information clarifies their intent.'
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   }
# }

# %%
session.run_day_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=[], gm_event_cursor=0)

# %%
session.run_vote_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=[], gm_event_cursor=0)

# %%
session.run_result_step()
pprint(session.world_state)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
