# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from rich.pretty import pprint

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

pprint(session.world_state)
pprint(session.player_states)
pprint(session.controllers)
pprint(session.assigned_roles)
pprint(session.gm_internal)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.core.session import GameSession
#       2 from src.game.one_night import ONE_NIGHT_GAME_DEFINITION
#       4 session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/__init__.py:1
# ----> 1 from .types import (
#       2     PlayerState,
#       3     GameDefinition,
#       4     PlayerMemory,
#       5     PlayerInput,
#       6     PlayerOutput,
#       7     WorldState,
#       8     RoleDefinition,
#       9     RoleName,
#      10     Side,
#      11     DaySide,
#      12     WinSide,
#      13     Phase,
#      14     GameEventType,
#      15     PlayerRequestType,
#      16     GameEvent,
#      17     PlayerRequest,
#      18 )
#      19 from .session import GameSession
#      21 __all__ = [
#      22     "PlayerState",
#      23     "GameDefinition",
#    (...)     38     "GameSession",
#      39 ]
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/types/__init__.py:33
#      25 from src.core.types.events import (
#      26     GameEventType,
#      27     GameEvent,
#      28     PlayerRequestType,
#      29     PlayerRequest,
#      30 )
#      32 # プレイヤー関連
# ---> 33 from src.core.types.player import (
#      34     PlayerName,
#      35     PlayerMemory,
#      36     PlayerInput,
#      37     PlayerOutput,
#      38     PlayerState,
#      39     NoAbility,
#      40     SeerAbility,
#      41     WerewolfAbility,
#      42     AbilityResult,
#      43 )
#      45 # フェーズ・ゲーム定義・ワールド状態
#      46 from src.core.types.phases import (
#      47     Phase,
#      48     GameDefinition,
#      49     WorldState,
#      50     GameResult,
#      51 )
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/types/player.py:16
#      14 from src.core.types.roles import RoleName
#      15 from src.core.types.events import GameEvent, PlayerRequest, PlayerRequestType
# ---> 16 from .phases import WorldState
#      18 __all__ = [
#      19     "PlayerName",
#      20     "PlayerMemory",
#    (...)     27     "AbilityResult",
#      28 ]
#      31 # =========================
#      32 # プレイヤーを識別するための名前型
#      33 # =========================
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/types/phases.py:15
#      12 from pydantic import BaseModel
#      14 from src.core.types.roles import RoleName, RoleDefinition, Side
# ---> 15 from src.core.types.player import PlayerName
#      16 from src.core.types.events import GameEvent
#      18 __all__ = [
#      19     "Phase",
#      20     "GameDefinition",
#      21     "WorldState",
#      22     "GameResult",
#      23 ]
#
# ImportError: cannot import name 'PlayerName' from partially initialized module 'src.core.types.player' (most likely due to a circular import) (/home/soyu/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/types/player.py)

# %%
session.run_night_phase()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# use_ability
# use_ability
# use_ability
# use_ability
# use_ability
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=['太郎', '花子', 'さくら', '次郎', '健太'], gm_event_cursor=0)

# %%
session.run_day_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=['太郎', '花子', 'さくら', '次郎', '健太'], gm_event_cursor=0)

# %%
session.run_vote_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
# GMInternalState(night_pending=['太郎', '花子', 'さくら', '次郎', '健太'], gm_event_cursor=0)

# %%
session.run_result_step()
pprint(session.world_state)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(phase='day', players=['太郎', '花子', '次郎', 'さくら', '健太'], public_events=[], result=None)
