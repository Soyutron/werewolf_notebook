# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from rich.pretty import pprint

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

# pprint(session.world_state)
# pprint(session.controllers)
# pprint(session.assigned_roles)
# pprint(session.gm_internal)
# pprint(session.player_states)

# %%
session.run_night_phase()
pprint(session.world_state)
pprint(session.gm_internal)
pprint(session.player_states)
# Out:
# kind='night_started' text='A chill settles.'
# kind='GameEvent' text='Shadows lengthen.'
# kind='observation' text='Silence.'
# kind='night_started' text='Cold.'
# kind='observation' text='Shadows lengthen.'
# kind='observation' text='Something feels…wrong.'
# kind='player_request' text='A coldness… it’s coming.'
# kind='panic' text="They're watching."
# kind='Observation' text='A chill runs down my spine.'
# kind='player_request' text='A shadow feels close.'
# kind='gameevent' text='The veil thins. A whisper of something ancient stirs within the shadows.'
# WorldState(
# │   phase='night',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )
# GMInternalState(
# │   night_started=True,
# │   day_started=False,
# │   night_pending=[],
# │   discussion_turn=0,
# │   max_discussion_turn=10,
# │   gm_event_cursor=1
# )
# {
# │   '太郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='太郎',
# │   │   │   self_role='seer',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[
# │   │   │   │   GameEvent(event_type='night_started', payload={}),
# │   │   │   │   GameEvent(event_type='divine_result', payload={'target': '次郎', 'role': 'madman'})
# │   │   │   ],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.0, 'seer': 1.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   Reaction(kind='night_started', text='A chill settles.'),
# │   │   │   │   Reaction(kind='player_request', text='A shadow feels close.'),
# │   │   │   │   Reflection(
# │   │   │   │   │   kind='gameevent',
# │   │   │   │   │   text='The veil thins. A whisper of something ancient stirs within the shadows.'
# │   │   │   │   )
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(
# │   │   │   event=GameEvent(event_type='divine_result', payload={'target': '次郎', 'role': 'madman'}),
# │   │   │   request=None
# │   │   ),
# │   │   'output': None
# │   },
# │   '花子': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='花子',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   Reaction(kind='GameEvent', text='Shadows lengthen.'),
# │   │   │   │   Reaction(kind='Observation', text='A chill runs down my spine.')
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   '次郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='次郎',
# │   │   │   self_role='madman',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 1.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   Reaction(kind='observation', text='Silence.'),
# │   │   │   │   Reaction(kind='panic', text="They're watching.")
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   'さくら': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='さくら',
# │   │   │   self_role='werewolf',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 1.0, 'madman': 0.0}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   Reaction(kind='night_started', text='Cold.'),
# │   │   │   │   Reaction(kind='player_request', text='A coldness… it’s coming.')
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=WerewolfAbility(kind='werewolf'))
# │   },
# │   '健太': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='健太',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   Reaction(kind='observation', text='Shadows lengthen.'),
# │   │   │   │   Reaction(kind='observation', text='Something feels…wrong.')
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   }
# }

# %%
session.run_night_phase()
pprint(session.world_state)
# Out:
# WorldState(
# │   phase='day',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )

# %%
session.run_day_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# {'speaker': '花子', 'text': '夜の始まりですね。皆さんのキャラクター設定を教えてください。'}
# kind='gameevent' text='Something watches.'
# kind='GameEvent' text='Something feels wrong.'
# kind='observation' text='Damn, they’re all looking at me.'
# kind='event' text='The air feels thick.'
# kind='event' text='Darkness descends.'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 session.run_day_step()
#       2 pprint(session.world_state)
#       3 pprint(session.gm_internal)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/session/game_session.py:359, in GameSession.run_day_step(self)
#     353 def run_day_step(self) -> None:
#     354     """
#     355     昼フェーズ（議論フェーズ）の 1 ステップを実行する。
#     356
#     357     この実装は PhaseRunner クラスに委譲する。
#     358     """
# --> 359     self._phase_runner.run_day_step(session=self)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/session/phase_runner.py:82, in PhaseRunner.run_day_step(self, session)
#      60 """
#      61 昼フェーズ（議論フェーズ）の 1 ステップを実行する。
#      62
#    (...)     79   発言イベントなどを追加した後に 1 回だけ呼び出す
#      80 """
#      81 gm_graph_state = session.run_gm_step()
# ---> 82 session.dispatch(gm_graph_state["decision"])
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/session/game_session.py:317, in GameSession.dispatch(self, decision)
#     310 def dispatch(self, decision: GameDecision) -> None:
#     311     """
#     312     GMGraph から返された GameDecision を受け取り、
#     313     実際のゲーム世界（WorldState / PlayerState）に反映する。
#     314
#     315     この実装は Dispatcher クラスに委譲する。
#     316     """
# --> 317     self._dispatcher.dispatch(decision, session=self)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/session/dispatcher.py:71, in Dispatcher.dispatch(self, decision, session)
#      68 for event in decision.events:
#      69     for player in session.player_states:
#      70         # event は「観測情報」なので全員に配布する
# ---> 71         session.run_player_turn(
#      72             player=player,
#      73             input=PlayerInput(event=event),
#      74         )
#      75 # event は全員に配布し終えた後で、
#      76 # 公開ログ（WorldState）として確定させる
#      77 session.world_state.public_events.extend(decision.events)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/session/game_session.py:257, in GameSession.run_player_turn(self, player, input)
#     252 working_state["output"] = None
#     254 # --- 次の状態を計算 ---
#     255 # Controller（内部で PlayerGraph を使用）が
#     256 # working_state をもとに次の状態を生成する
# --> 257 new_state = controller.act(state=working_state)
#     259 # --- 結果の確定保存 ---
#     260 # 計算された state を正式な状態として保存
#     261 # （state の確定・永続化は GameSession の責務）
#     262 self.player_states[player] = new_state
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/core/controller.py:69, in AIPlayerController.act(self, state)
#      66 working_state = deepcopy(state)
#      68 # PlayerGraph による思考・行動の実行（state 遷移）
# ---> 69 new_state = self.player_graph.invoke(working_state)
#      71 # 計算された新しい state を Session に返す
#      72 return new_state
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/graphs/player/player_graph.py:42, in LangGraphPlayerAdapter.invoke(self, state)
#      41 def invoke(self, state: PlayerState) -> PlayerState:
# ---> 42     return self.graph.invoke(state)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:658, in RunnableSeq.invoke(self, input, config, **kwargs)
#     656                 input = context.run(step.invoke, input, config, **kwargs)
#     657         else:
# --> 658             input = step.invoke(input, config)
#     659 # finish the root run
#     660 except BaseException as e:
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/graph/_branch.py:166, in BranchSpec._route(self, input, config, reader, writer)
#     164 else:
#     165     value = input
# --> 166 result = self.path.invoke(value, config)
#     167 return self._finish(writer, input, result, config)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:393, in RunnableCallable.invoke(self, input, config, **kwargs)
#     391     # run in context
#     392     with set_config_context(child_config, run) as context:
# --> 393         ret = context.run(self.func, *args, **kwargs)
#     394 except BaseException as e:
#     395     run_manager.on_chain_error(e)
#
# File ~/Projects/LangGraph/ai-worf/werewolf_notebook/src/graphs/player/phase_router.py:31, in phase_router(state)
#      26     return "use_ability"
#      28 # -------------------------
#      29 # どれにも当てはまらないのは設計ミス
#      30 # -------------------------
# ---> 31 raise RuntimeError(
#      32     player_input,
#      33     "phase_router: neither event nor request is present in PlayerInput",
#      34 )
#
# RuntimeError: (PlayerInput(event=GameEvent(event_type='gm_comment', payload={'text': '夜の始まりですね。皆さんのキャラクター設定を教えてください。', 'speaker': '花子'}), request=None), 'phase_router: neither event nor request is present in PlayerInput')
# During task with name '__start__' and id 'f32a1bef-9b45-ae15-bde1-cfbf4bde3f8d'

# %%
session.run_vote_step()
pprint(session.world_state)
pprint(session.gm_internal)

# %%
session.run_result_step()
pprint(session.world_state)
