# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from rich.pretty import pprint

# %%
from src.core.session import GameSession
from src.game.one_night import ONE_NIGHT_GAME_DEFINITION

session = GameSession.create(definition=ONE_NIGHT_GAME_DEFINITION)

# pprint(session.world_state)
# pprint(session.controllers)
# pprint(session.assigned_roles)
# pprint(session.gm_internal)
# pprint(session.player_states)

# %%
session.run_night_phase()
pprint(session.world_state)
pprint(session.gm_internal)
pprint(session.player_states)
# Out:
# {'kind': 'game_event', 'text': 'Something feels…heavy.'}
# {'kind': 'event', 'text': 'Shadows lengthen.'}
# {'kind': 'observation', 'text': 'Silence...heavy.'}
# {'kind': 'night_started', 'text': 'Cold.'}
# {'kind': 'observation', 'text': 'Shadows lengthen.'}
# {'kind': 'urgent', 'text': 'Something feels wrong.'}
# {'kind': 'reaction', 'text': 'Quiet...it tastes like blood.'}
# {'kind': 'gut', 'text': 'A chill settles.'}
# {'kind': 'observation', 'text': 'A chill settles.'}
# {'kind': 'request', 'text': 'A pull, a whisper of something unseen.'}
# {'kind': 'strategic', 'text': 'Knowing Taro is a villager significantly narrows the possibilities; I must now carefully consider who else might be a werewolf to avoid prematurely eliminating a valuable ally. Next investigation should prioritize those with the highest werewolf probability to maximize information gain. This also reinforces the need to be subtle in my future actions, lest I draw unwanted attention.'}
# WorldState(
# │   phase='night',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )
# GMInternalState(night_started=True, night_pending=[], gm_event_cursor=1)
# {
# │   '太郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='太郎',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {'kind': 'game_event', 'text': 'Something feels…heavy.'},
# │   │   │   │   {'kind': 'gut', 'text': 'A chill settles.'}
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   '花子': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='花子',
# │   │   │   self_role='seer',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[
# │   │   │   │   GameEvent(event_type='night_started', payload={}),
# │   │   │   │   GameEvent(event_type='divine_result', payload={'target': '太郎', 'role': 'villager'})
# │   │   │   ],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.0, 'seer': 1.0, 'werewolf': 0.0, 'madman': 0.0}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {'kind': 'event', 'text': 'Shadows lengthen.'},
# │   │   │   │   {'kind': 'request', 'text': 'A pull, a whisper of something unseen.'},
# │   │   │   │   {
# │   │   │   │   │   'kind': 'strategic',
# │   │   │   │   │   'text': 'Knowing Taro is a villager significantly narrows the possibilities; I must now carefully consider who else might be a werewolf to avoid prematurely eliminating a valuable ally. Next investigation should prioritize those with the highest werewolf probability to maximize information gain. This also reinforces the need to be subtle in my future actions, lest I draw unwanted attention.'
# │   │   │   │   }
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(
# │   │   │   event=GameEvent(event_type='divine_result', payload={'target': '太郎', 'role': 'villager'}),
# │   │   │   request=None
# │   │   ),
# │   │   'output': None
# │   },
# │   '次郎': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='次郎',
# │   │   │   self_role='madman',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 1.0}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {'kind': 'observation', 'text': 'Silence...heavy.'},
# │   │   │   │   {'kind': 'reaction', 'text': 'Quiet...it tastes like blood.'}
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   },
# │   'さくら': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='さくら',
# │   │   │   self_role='werewolf',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.0, 'seer': 0.0, 'werewolf': 1.0, 'madman': 0.0}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {'kind': 'night_started', 'text': 'Cold.'},
# │   │   │   │   {'kind': 'urgent', 'text': 'Something feels wrong.'}
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=WerewolfAbility(kind='werewolf'))
# │   },
# │   '健太': {
# │   │   'memory': PlayerMemory(
# │   │   │   self_name='健太',
# │   │   │   self_role='villager',
# │   │   │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   │   │   observed_events=[GameEvent(event_type='night_started', payload={})],
# │   │   │   role_beliefs={
# │   │   │   │   '太郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '花子': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '次郎': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   'さくら': RoleProb(probs={'villager': 0.4, 'seer': 0.2, 'werewolf': 0.2, 'madman': 0.2}),
# │   │   │   │   '健太': RoleProb(probs={'villager': 1.0, 'seer': 0.0, 'werewolf': 0.0, 'madman': 0.0})
# │   │   │   },
# │   │   │   history=[
# │   │   │   │   {'kind': 'observation', 'text': 'Shadows lengthen.'},
# │   │   │   │   {'kind': 'observation', 'text': 'A chill settles.'}
# │   │   │   ]
# │   │   ),
# │   │   'input': PlayerInput(event=None, request=PlayerRequest(request_type='use_ability', payload={})),
# │   │   'output': PlayerOutput(action='use_ability', payload=NoAbility(kind='none'))
# │   }
# }

# %%
session.run_night_phase()
pprint(session.world_state)
# Out:
# WorldState(
# │   phase='day',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )

# %%
session.run_day_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(
# │   phase='day',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )
# GMInternalState(night_started=True, night_pending=[], gm_event_cursor=1)

# %%
session.run_vote_step()
pprint(session.world_state)
pprint(session.gm_internal)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(
# │   phase='day',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )
# GMInternalState(night_started=True, night_pending=[], gm_event_cursor=1)

# %%
session.run_result_step()
pprint(session.world_state)
# Out:
# Task __start__ with path ('__pregel_pull', '__start__') wrote to unknown channel branch:to:day, ignoring it.
# WorldState(
# │   phase='day',
# │   players=['太郎', '花子', '次郎', 'さくら', '健太'],
# │   public_events=[GameEvent(event_type='night_started', payload={})],
# │   result=None
# )
